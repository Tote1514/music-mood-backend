# %%
pip install text2emotion
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import text2emotion as te
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\josea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\josea\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\josea\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
pip install emoji==1.6.3

# %%
# Testando em portugues
frases_emocoes = [
    "Ansioso para amanhã, me recomenda algo relaxante para ouvir antes de dormir?",
    "Tô meio triste, queria ouvir algo mais calmo, tipo uma balada melancólica.",
    "Estou muito feliz hoje, quero uma música animada para comemorar.",
    "Acabei de passar numa prova difícil, preciso de uma trilha sonora para comemorar!",
    "Tá chovendo e eu só queria uma playlist tranquila para ficar em casa.",
    "Terminei um relacionamento, não quero nada muito animado agora.",
    "Tá chovendo e eu só queria uma playlist tranquila para ficar em casa.",
    "Estou com muita raiva, preciso de um som pesado para descarregar.",
    "Bateu uma saudade enorme, queria ouvir músicas que me lembrem minha infância.",
    "Tô nostálgico hoje, me recomenda umas músicas antigas dos anos 90?",
    "Ansioso e sem foco, preciso de algo instrumental para me acalmar.",
    "Estou eufórico, quero músicas bem agitadas para manter a energia lá em cima!",
    "Tô entediado, manda qualquer coisa diferente para eu descobrir artistas novos.",
    "Preciso de músicas inspiradoras para me motivar a começar a semana.",
    "Estou apaixonado, quero músicas românticas para entrar no clima.",
    "Sinto um vazio, quero algo profundo e reflexivo."
]

for frase in frases_emocoes:
    emocao = te.get_emotion(frase)
    print(f"Frase: {frase}")
    print(f"Emoções detectadas: {emocao}")
    print("-" * 50)
# Out:
# Frase: Ansioso para amanhã, me recomenda algo relaxante para ouvir antes de dormir?
# Emoções detectadas: {'Happy': 0, 'Angry': 0, 'Surprise': 0, 'Sad': 0, 'Fear': 0}
# --------------------------------------------------
# Frase: Tô meio triste, queria ouvir algo mais calmo, tipo uma balada melancólica.
# Emoções detectadas: {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 1.0, 'Fear': 0.0}
# --------------------------------------------------
# Frase: Estou muito feliz hoje, quero uma música animada para comemorar.
# Emoções detectadas: {'Happy': 0, 'Angry': 0, 'Surprise': 0, 'Sad': 0, 'Fear': 0}
# --------------------------------------------------
# Frase: Acabei de passar numa prova difícil, preciso de uma trilha sonora para comemorar!
# Emoções detectadas: {'Happy': 0, 'Angry': 0, 'Surprise': 0, 'Sad': 0, 'Fear': 0}
# --------------------------------------------------
# Frase: Tá chovendo e eu só queria uma playlist tranquila para ficar em casa.
# ...

# %%
# Testando em ingles
frases_emocoes_en = [
    "Anxious about tomorrow, can you recommend something relaxing to listen to before bed?",
    "I'm kind of sad, I'd like to hear something calmer, like a melancholic ballad.",
    "I'm very happy today, I want an upbeat song to celebrate.",
    "I just passed a difficult exam, I need a soundtrack to celebrate!",
    "It's raining and I just want a calm playlist to stay at home.",
    "I ended a relationship, I don't want anything too lively right now.",
    "It's raining and I just wanted a calm playlist to stay at home.",
    "I'm really angry, I need some heavy music to blow off steam.",
    "I felt a huge longing, I want to hear songs that remind me of my childhood.",
    "I'm nostalgic today, recommend me some old songs from the 90s.",
    "Anxious and unfocused, I need something instrumental to calm me down.",
    "I'm euphoric, I want very energetic songs to keep the energy up!",
    "I'm bored, send me anything different so I can discover new artists.",
    "I need inspiring songs to motivate me to start the week.",
    "I'm in love, I want romantic songs to set the mood.",
    "I feel empty, I want something deep and reflective."
]
for frase in frases_emocoes_en:
    emocao = te.get_emotion(frase)
    print(f"Frase: {frase}")
    print(f"Emoções detectadas: {emocao}")
    print("-" * 50)
# Out:
# Frase: Anxious about tomorrow, can you recommend something relaxing to listen to before bed?
# Emoções detectadas: {'Happy': 0.0, 'Angry': 0.0, 'Surprise': 0.5, 'Sad': 0.0, 'Fear': 0.5}
# --------------------------------------------------
# Frase: I'm kind of sad, I'd like to hear something calmer, like a melancholic ballad.
# Emoções detectadas: {'Happy': 0.5, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.5, 'Fear': 0.0}
# --------------------------------------------------
# Frase: I'm very happy today, I want an upbeat song to celebrate.
# Emoções detectadas: {'Happy': 1.0, 'Angry': 0.0, 'Surprise': 0.0, 'Sad': 0.0, 'Fear': 0.0}
# --------------------------------------------------
# Frase: I just passed a difficult exam, I need a soundtrack to celebrate!
# Emoções detectadas: {'Happy': 0, 'Angry': 0, 'Surprise': 0, 'Sad': 0, 'Fear': 0}
# --------------------------------------------------
# Frase: It's raining and I just want a calm playlist to stay at home.
# ...

# %%
text = "I was asked to sign a third party contract a week out from stay. If it wasn't an 8 person group that took a lot of wrangling I would have cancelled the booking straight away. Bathrooms - there are no stand alone bathrooms. Please consider this - you have to clear out the main bedroom to use that bathroom. Other option is you walk through a different bedroom to get to its en-suite. Signs all over the apartment - there are signs everywhere - some helpful - some telling you rules. Perhaps some people like this but It negatively affected our enjoyment of the accommodation. Stairs - lots of them - some had slightly bending wood which caused a minor injury."

# %%
te.get_emotion(text, language='en')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 text = "Day was pretty amazing😃😃"
# ----> 2 te.get_emotion(text)
#
# File c:\Users\josea\OneDrive\Área de Trabalho\backend-projects\music-mood-backend\.venv\Lib\site-packages\text2emotion\__init__.py:2716, in get_emotion(input)
#    2713     # print(clean_text)
#    2714     return clean_text
# -> 2716 text = cleaning(input).split()
#    2717 emotion_values = []
#    2718 emotions = {"Happy": 0, "Angry": 0, "Surprise": 0, "Sad": 0, "Fear": 0}
#
# File c:\Users\josea\OneDrive\Área de Trabalho\backend-projects\music-mood-backend\.venv\Lib\site-packages\text2emotion\__init__.py:2700, in get_emotion.<locals>.cleaning(text)
#    2698 def cleaning(text):
#    2699     text = text.lower()
# -> 2700     text = emojis_extractor(text)
#    2701     text = re.sub(r'http\S+|www.\S+', '', text)
# ...
